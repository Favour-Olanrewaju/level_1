# %% [markdown]
# # Data Cleaning and Preprocessing

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\USER\\Downloads\\sample_employee_data.csv")
data.head()
# Out:
#       Name   Age Gender Department   Salary JoiningDate
# 0    Alice  25.0      F         HR  50000.0  2015-03-01
# 1      Bob   NaN      M    Finance  60000.0  2018-07-15
# 2  Charlie  35.0      M         IT  80000.0  2016-08-21
# 3    David  45.0      M         IT      NaN  2017-11-10
# 4      Eve  22.0      F         HR  45000.0  2019-01-20

# %%
data.shape
# Out:
# (10, 6)

# %%
data[data.isnull()].any()
# Out:
# Name           False
# Age            False
# Gender         False
# Department     False
# Salary         False
# JoiningDate    False
# dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         10 non-null     object
#  1   Age          8 non-null      float64
#  2   Gender       10 non-null     object
#  3   Department   10 non-null     object
#  4   Salary       8 non-null      float64
#  5   JoiningDate  10 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 612.0+ bytes

# %%
# Fill missing values with mean
data['Age'].fillna(data['Age'].mean(), inplace=True)

# Drop rows with missing values
data.dropna(subset=['Salary'], inplace=True)

# Check after cleaning
print(data.isnull().sum())
# Out:
# Name           0
# Age            0
# Gender         0
# Department     0
# Salary         0
# JoiningDate    0
# dtype: int64

# %% [markdown]
#  # Encoding Categorical Variables

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Label Encoding
label_encoder= LabelEncoder()
data['Gender'] = label_encoder.fit_transform(data['Gender'])

# One-Hot Encoding
encoded = pd.get_dummies(data['Department'], prefix='Dept')
data = pd.concat([data, encoded], axis=1)

data.head()
# Out:
#       Name    Age  Gender Department   Salary JoiningDate  Dept_Finance  \
# 0    Alice  25.00       0         HR  50000.0  2015-03-01         False
# 1      Bob  33.25       1    Finance  60000.0  2018-07-15          True
# 2  Charlie  35.00       1         IT  80000.0  2016-08-21         False
# 4      Eve  22.00       0         HR  45000.0  2019-01-20         False
# 5    Frank  33.00       1  Marketing  70000.0  2015-05-30         False
#
#    Dept_HR  Dept_IT  Dept_Marketing  ...  Dept_IT  Dept_Marketing  \
# 0     True    False           False  ...    False           False
# 1    False    False           False  ...    False           False
# 2    False     True           False  ...     True           False
# 4     True    False           False  ...    False           False
# 5    False    False            True  ...    False            True
#
#    Dept_Finance  Dept_HR  Dept_IT  Dept_Marketing  Dept_Finance  Dept_HR  \
# 0         False     True    False           False         False     True
# 1          True    False    False           False          True    False
# 2         False    False     True           False         False    False
# 4         False     True    False           False         False     True
# 5         False    False    False            True         False    False
#
#    Dept_IT  Dept_Marketing
# 0    False           False
# 1    False           False
# 2     True           False
# 4    False           False
# 5    False            True
#
# [5 rows x 22 columns]

# %% [markdown]
# # Feature Scaling and Normalization

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Standardization
scaler = StandardScaler()
data[['Age', 'Salary']] = scaler.fit_transform(data[['Age', 'Salary']])

# Normalization
minmax = MinMaxScaler()
data[['Age', 'Salary']] = minmax.fit_transform(data[['Age', 'Salary']])

data.head()
# Out:
#       Name       Age  Gender Department    Salary JoiningDate  Dept_Finance  \
# 0    Alice  0.166667       0         HR  0.142857  2015-03-01         False
# 1      Bob  0.625000       1    Finance  0.428571  2018-07-15          True
# 2  Charlie  0.722222       1         IT  1.000000  2016-08-21         False
# 4      Eve  0.000000       0         HR  0.000000  2019-01-20         False
# 5    Frank  0.611111       1  Marketing  0.714286  2015-05-30         False
#
#    Dept_HR  Dept_IT  Dept_Marketing  ...  Dept_IT  Dept_Marketing  \
# 0     True    False           False  ...    False           False
# 1    False    False           False  ...    False           False
# 2    False     True           False  ...     True           False
# 4     True    False           False  ...    False           False
# 5    False    False            True  ...    False            True
#
#    Dept_Finance  Dept_HR  Dept_IT  Dept_Marketing  Dept_Finance  Dept_HR  \
# 0         False     True    False           False         False     True
# 1          True    False    False           False          True    False
# 2         False    False     True           False         False    False
# 4         False     True    False           False         False     True
# 5         False    False    False            True         False    False
#
#    Dept_IT  Dept_Marketing
# 0    False           False
# 1    False           False
# 2     True           False
# 4    False           False
# 5    False            True
#
# [5 rows x 22 columns]
